# %% [markdown]
# # Etapa 2 — Decision Tree (implementación propia)
#
# **Objetivo:** implementar el algoritmo Decision Tree desde cero y evaluarlo.
#
# **Entradas:** `X_train, X_test, y_train, y_test` de la etapa 1.
# **Salidas:** modelo `DecisionTree` entrenado + métricas de train/test.
#
# **Restricción:** no usar `sklearn.tree`. El árbol lo implementa el equipo.
#
# **Checklist:**
# - [ ] Definir la clase `DecisionTree` (`fit` / `predict`)
# - [ ] Implementar impureza (Gini y/o Entropy)
# - [ ] Implementar la búsqueda del mejor split
# - [ ] Implementar el criterio de corte (`max_depth`, `min_samples_split`)
# - [ ] Entrenar y predecir
# - [ ] Calcular métricas y matriz de confusión

# %%
# Imports base (agregar los que falten)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Métricas para evaluar (permitido)
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay,
)

# IMPORTANTE: no importar sklearn.tree, el DT es de elaboración propia.

# %%
class DecisionTree:
    """Árbol de decisión propio (sin usar sklearn.tree)."""

    def __init__(self, criterion="gini", max_depth=None, min_samples_split=2):
        # TODO: guardar hiperparámetros
        ...

    def fit(self, X, y):
        # TODO: construir el árbol recursivamente
        ...

    def predict(self, X):
        # TODO: recorrer el árbol para clasificar cada fila
        ...

    # TODO: helpers sugeridos
    # def _gini(self, y): ...
    # def _entropy(self, y): ...
    # def _best_split(self, X, y): ...

# %%
# TODO: entrenar y predecir
# arbol = DecisionTree(criterion="gini", max_depth=5)
# arbol.fit(X_train, y_train)
# y_pred_train = arbol.predict(X_train)
# y_pred_test = arbol.predict(X_test)

# %%
# TODO: métricas de train y test
# accuracy_score, precision_score, recall_score, f1_score (usar average="weighted" si es multiclase)
# confusion_matrix + ConfusionMatrixDisplay.from_predictions(...)

# %%
# TODO: (opcional) persistir el modelo para las etapas 4 y 5
# import joblib; joblib.dump(arbol, "data/decision_tree.joblib")

# %% [markdown]
# ## Problemas encontrados
#
# _(Anotar acá los problemas y decisiones de la etapa 2 para el informe.)_
