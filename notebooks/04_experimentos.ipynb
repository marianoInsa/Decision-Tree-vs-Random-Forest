# %% [markdown]
# # Etapa 4 — Experimentos: DT vs RF
#
# **Objetivo:** comparar ambos modelos variando hiperparámetros y registrar los resultados
# para el informe.
#
# **Entradas:** `X_train, X_test, y_train, y_test` de la etapa 1 (y/o modelos de las etapas 2 y 3).
# **Salidas:** tabla comparativa de métricas y tiempos + gráficos + CSV de resultados.
#
# **Checklist:**
# - [ ] Definir la grilla de hiperparámetros de cada modelo
# - [ ] Entrenar y evaluar cada combinación (DT y RF)
# - [ ] Medir accuracy, precision, recall, F1 y tiempo de entrenamiento
# - [ ] Armar la tabla comparativa
# - [ ] Graficar la evolución de las métricas
# - [ ] Exportar resultados a CSV

# %%
# Imports base (agregar los que falten)
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
)

# %%
# TODO: dejar disponibles la clase DecisionTree (etapa 2) y el RF (etapa 3)
# En local:  %run ./02_decision_tree.ipynb
# En Colab:  copiar la clase en este notebook o clonar el repo antes

# %%
# TODO: grillas de hiperparámetros a comparar
# grilla_dt = {"criterion": ["gini", "entropy"], "max_depth": [None, 3, 5, 10]}
# grilla_rf = {"n_estimators": [10, 50, 100], "max_depth": [None, 3, 5, 10]}

# %%
# TODO: entrenar y evaluar cada combinación (accuracy, precision, recall, f1, tiempo)
# resultados = []
# for ... : resultados.append({...})
# resultados = pd.DataFrame(resultados)

# %%
# TODO: tabla comparativa DT vs RF
# resultados.sort_values(["modelo", "f1"]).groupby("modelo").head(3)

# %%
# TODO: gráficos (ej: F1 en función de max_depth, DT vs RF)
# resultado.plot(...)

# %%
# TODO: exportar para el informe
# resultados.to_csv("data/resultados_experimentos.csv", index=False)

# %% [markdown]
# ## Problemas encontrados
#
# _(Anotar acá los problemas y decisiones de la etapa 4 para el informe.)_
