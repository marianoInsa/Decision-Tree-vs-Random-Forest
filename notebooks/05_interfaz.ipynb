# %% [markdown]
# # Etapa 5 — Interfaz amigable (ipywidgets)
#
# **Objetivo:** interfaz que permita correr pruebas fácilmente y ver los resultados
# (requisito del enunciado). Este es el **notebook final autocontenido**: debe incluir la
# clase `DecisionTree` (etapa 2), el RF (etapa 3) y la UI.
#
# **Entradas:** dataset (etapa 1).
# **Salidas:** métricas y gráficos por pantalla según lo que elija el usuario.
#
# **Checklist:**
# - [ ] Definir los modelos (DT propio + RF de sklearn) en este notebook
# - [ ] Armar los controles: dataset, modelo, hiperparámetros, botón "Entrenar y evaluar"
# - [ ] Mostrar métricas y matriz de confusión en un área de salida
# - [ ] Probar distintos valores desde los controles
# - [ ] Verificar que corra de punta a punta en Google Colab

# %%
# Imports base (agregar los que falten)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay,
)

# %%
# TODO: definir acá la clase DecisionTree (copiada de la etapa 2)
# TODO: definir acá la carga del dataset y el split (etapa 1)
# (Este notebook debe poder ejecutarse solo, de arriba a abajo, en Colab.)

# %%
# TODO: armar los controles de la interfaz
# Ejemplo mínimo del patrón a seguir:
#
# modelo = widgets.Dropdown(options=["Decision Tree", "Random Forest"], description="Modelo")
# max_depth = widgets.IntSlider(value=5, min=1, max=20, description="Prof. máx.")
# boton = widgets.Button(description="Entrenar y evaluar", button_style="success")
# salida = widgets.Output()
#
# def al_click(b):
#     with salida:
#         salida.clear_output()
#         # TODO: entrenar el modelo elegido, predecir y mostrar métricas
#
# boton.on_click(al_click)
# display(widgets.VBox([modelo, max_depth, boton, salida]))

# %%
# TODO: mostrar resultados
# - métricas (accuracy, precision, recall, f1)
# - matriz de confusión (ConfusionMatrixDisplay)
# - gráfico comparativo si se evalúan ambos modelos

# %% [markdown]
# ## Problemas encontrados
#
# _(Anotar acá los problemas y decisiones de la etapa 5 para el informe.)_
