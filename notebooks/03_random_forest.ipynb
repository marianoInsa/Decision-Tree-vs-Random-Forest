# %% [markdown]
# # Etapa 3 — Random Forest (Scikit-learn)
#
# **Objetivo:** entrenar y evaluar el modelo Random Forest de Scikit-learn.
#
# **Entradas:** `X_train, X_test, y_train, y_test` de la etapa 1.
# **Salidas:** modelo RF entrenado + métricas de train/test.
#
# **Checklist:**
# - [ ] Entrenar RF con parámetros por defecto (baseline)
# - [ ] Evaluar con las mismas métricas que el DT
# - [ ] Probar variaciones de `n_estimators`, `max_depth`, `max_features`
# - [ ] (Opcional) ver importancia de variables

# %%
# Imports base (agregar los que falten)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay,
)

# %%
# TODO: baseline con parámetros por defecto
# rf = RandomForestClassifier(random_state=42)
# rf.fit(X_train, y_train)
# y_pred_test = rf.predict(X_test)

# %%
# TODO: métricas con la misma función/criterio que en la etapa 2
# accuracy, precision, recall, f1, matriz de confusión

# %%
# TODO: variar hiperparámetros
# for n in [10, 50, 100]: ...
# for d in [None, 3, 5, 10]: ...

# %%
# TODO: (opcional) importancia de variables
# pd.Series(rf.feature_importances_, index=X.columns).sort_values().plot.barh()

# %%
# TODO: (opcional) persistir el modelo para las etapas 4 y 5
# import joblib; joblib.dump(rf, "data/random_forest.joblib")

# %% [markdown]
# ## Problemas encontrados
#
# _(Anotar acá los problemas y decisiones de la etapa 3 para el informe.)_
