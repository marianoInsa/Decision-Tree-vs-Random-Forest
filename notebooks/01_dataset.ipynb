# %% [markdown]
# # Etapa 1 — Dataset
#
# **Objetivo:** cargar el dataset indicado por la cátedra, explorarlo y dejarlo listo para entrenar.
#
# **Entradas:** archivo del dataset (CSV / Excel / URL).
# **Salidas:** `X_train, X_test, y_train, y_test` + resumen de exploración.
#
# **Checklist:**
# - [ ] Cargar el dataset
# - [ ] Ver forma, tipos y primeras filas
# - [ ] Revisar nulos, duplicados y balance de clases
# - [ ] Codificar variables categóricas / escalar si hace falta
# - [ ] Separar `X` e `y`
# - [ ] Split train/test (estratificado)
# - [ ] Guardar el split para las etapas siguientes

# %%
# Imports base (agregar los que falten)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from sklearn.model_selection import train_test_split

# %%
# TODO: cargar el dataset de la cátedra. Opciones:
#   from google.colab import files; files.upload()
#   pd.read_csv("data/dataset.csv")     # local o repo clonado
#   pd.read_csv("https://...")          # URL pública

# %%
# TODO: explorar el dataset
# df.shape, df.head(), df.info(), df.describe()
# df.isna().sum(), df.duplicated().sum()
# df["clase"].value_counts()

# %%
# TODO: preprocesar
# - codificar variables categóricas (pd.get_dummies / OrdinalEncoder)
# - escalar numéricas si el modelo lo necesita

# %%
# TODO: separar X e y y hacer el split
# X = df.drop(columns=["clase"])
# y = df["clase"]
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# TODO: guardar el split para reutilizarlo en las etapas 2, 3 y 4
# X_train.to_csv("data/X_train.csv", index=False)  # etc.

# %% [markdown]
# ## Problemas encontrados
#
# _(Anotar acá los problemas y decisiones de la etapa 1 para el informe.)_
